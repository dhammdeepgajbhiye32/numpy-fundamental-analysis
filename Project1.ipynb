# %%
# This project is Student Marks Analysis.

# Objective
# 1. Generate marks of 100 students(0-100)
# 2. Find mean, median, top scorers, failure count(<35)
# 3. Normaliz marks for curve grading.

# %%
import numpy as np

# Step 1: Generate marks of 100 students(0-100)

marks = np.random.randint(0,101, size = 100)
print(f"Marks of 100 students : \n {marks}")

# 1. Finding mean

mean_marks = np.mean(marks)
print(f"Mean Marks : {mean_marks}")

# 2. Finding median

median_marks = np.median(marks)
print(f"Median Marks : {median_marks}")

# 3. Finding top scorers

max_marks = np.max(marks)
print(f"Top scorers Marks : {max_marks}")

# 4. Finding lowest scorers
min_marks = np.min(marks)
print(f"Lowest scorers Marks : {min_marks}")

# 5. Finding failure count(<35)
fail_count = np.sum(marks < 35)
print(f"Failure Count (<35) : {fail_count}")

# 6. Normalizing marks for curve grading.
normalized_marks = (marks - np.min(marks)) / (np.max(marks) - np.min(marks)) * 100
print(f"Normalized Marks : \n {np.round(normalized_marks,2)}")

# End of the project
# Out:
# Marks of 100 students :
#  [17 25 15 21 77 65 47 63 66 79 97 89 33 50 69 52 93 86 60 82 44 38 71 19
#  36 14 81 29 95 50 88 42 93 35 32 65 99 25 94 93 24 23 69 41 38 23  3 84
#  69 37 22 59  0 54 33 12 56 82 50 59 80 45 72  4 62 50 40 44 65 57 93 75
#  21 60 14 91 16 50 48 50 80 57 64 44 72 97 68  4 75  1  0 49 13 58 16 91
#  99 42 58 50]
# Mean Marks : 52.42
# Median Marks : 51.0
# Top scorers Marks : 99
# Lowest scorers Marks : 0
# Failure Count (<35) : 27
# Normalized Marks :
#  [ 17.17  25.25  15.15  21.21  77.78  65.66  47.47  63.64  66.67  79.8
#   97.98  89.9   33.33  50.51  69.7   52.53  93.94  86.87  60.61  82.83
#   44.44  38.38  71.72  19.19  36.36  14.14  81.82  29.29  95.96  50.51
#   88.89  42.42  93.94  35.35  32.32  65.66 100.    25.25  94.95  93.94
#   24.24  23.23  69.7   41.41  38.38  23.23   3.03  84.85  69.7   37.37
#   22.22  59.6    0.    54.55  33.33  12.12  56.57  82.83  50.51  59.6
#   80.81  45.45  72.73   4.04  62.63  50.51  40.4   44.44  65.66  57.58
# ...
